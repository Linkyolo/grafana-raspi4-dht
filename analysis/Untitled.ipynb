# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from influxdb_client import InfluxDBClient
import os
from dotenv import load_dotenv
from utils import fetch_influx_data, query, load_and_clean_data

# %%
test = fetch_influx_data( query=query)
test
# Out:
#        result  table                           _start  \
# 0     _result      0 2026-07-25 09:33:36.488961+00:00
# 1     _result      0 2026-07-25 09:33:36.488961+00:00
# 2     _result      0 2026-07-25 09:33:36.488961+00:00
# 3     _result      0 2026-07-25 09:33:36.488961+00:00
# 4     _result      0 2026-07-25 09:33:36.488961+00:00
# ...       ...    ...                              ...
# 1607  _result      0 2026-07-25 09:33:36.488961+00:00
# 1608  _result      0 2026-07-25 09:33:36.488961+00:00
# 1609  _result      0 2026-07-25 09:33:36.488961+00:00
# 1610  _result      0 2026-07-25 09:33:36.488961+00:00
# 1611  _result      0 2026-07-25 09:33:36.488961+00:00
#
#                                 _stop                            _time  \
# 0    2026-07-25 12:33:36.488961+00:00 2026-07-25 09:58:26.900228+00:00
# 1    2026-07-25 12:33:36.488961+00:00 2026-07-25 09:58:32.213378+00:00
# 2    2026-07-25 12:33:36.488961+00:00 2026-07-25 09:58:37.486330+00:00
# ...

# %%
test.to_csv("data/days/25-luglio-2026.csv")

# %%
df = load_and_clean_data("data/days/25-luglio-2026.csv")
# Out:
# ----------------------------------------
# KeyErrorTraceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df = load_and_clean_data("data/days/25-luglio-2026.csv")
#
# File ~/dev/grapfana-raspi4-dht/analysis/utils.py:39, in load_and_clean_data(file_path)
#      36 df = pd.read_csv(file_path, parse_dates=["_time"])
#      38 # Pivot Table: righe di _field in colonne
# ---> 39 df_pivot = df.pivot_table(
#      40     index="_time", columns="_field", values="_value", aggfunc="mean"
#      41 )
#      43 # Resample: per serie temporali disomogenee
#      44 # Uniformiamo tutto su base minuto e interpoliamo i buchi.
#      45 return df_pivot.resample("min").mean().interpolate(method="linear")
#
# File ~/anaconda3/lib/python3.13/site-packages/pandas/core/frame.py:9536, in DataFrame.pivot_table(self, values, index, columns, aggfunc, fill_value, margins, dropna, margins_name, observed, sort)
#    9519 @Substitution("")
#    9520 @Appender(_shared_docs["pivot_table"])
# ...
